# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/titanic - titanic.csv')

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.countplot(data = df, x = 'Survived',palette='viridis')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='Survived',hue='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(data=df,x='Survived',hue='Pclass')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Cabin          687
# Age            177
# Embarked         2
# PassengerId      0
# Name             0
# Pclass           0
# Survived         0
# Sex              0
# Parch            0
# SibSp            0
# Fare             0
# Ticket           0
# dtype: int64

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Age            177
# Embarked         2
# PassengerId      0
# Pclass           0
# Survived         0
# Sex              0
# Name             0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Embarked       2
# Survived       0
# PassengerId    0
# Pclass         0
# Name           0
# Age            0
# Sex            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    object
#  5   Age          889 non-null    float64
#  6   SibSp        889 non-null    int64
#  7   Parch        889 non-null    int64
#  8   Ticket       889 non-null    object
#  9   Fare         889 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 83.3+ KB

# %%
df.drop(['PassengerId','Ticket','Embarked','Name'],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch     Fare
# 0           0       3    male  22.000000      1      0   7.2500
# 1           1       1  female  38.000000      1      0  71.2833
# 2           1       3  female  26.000000      0      0   7.9250
# 3           1       1  female  35.000000      1      0  53.1000
# 4           0       3    male  35.000000      0      0   8.0500
# ..        ...     ...     ...        ...    ...    ...      ...
# 886         0       2    male  27.000000      0      0  13.0000
# 887         1       1  female  19.000000      0      0  30.0000
# 888         0       3  female  29.699118      1      2  23.4500
# 889         1       1    male  26.000000      0      0  30.0000
# 890         0       3    male  32.000000      0      0   7.7500
#
# [889 rows x 7 columns]

# %%
df['Family'] = df['Parch'] + df['SibSp']

df
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch     Fare  Family
# 0           0       3    male  22.000000      1      0   7.2500       1
# 1           1       1  female  38.000000      1      0  71.2833       1
# 2           1       3  female  26.000000      0      0   7.9250       0
# 3           1       1  female  35.000000      1      0  53.1000       1
# 4           0       3    male  35.000000      0      0   8.0500       0
# ..        ...     ...     ...        ...    ...    ...      ...     ...
# 886         0       2    male  27.000000      0      0  13.0000       0
# 887         1       1  female  19.000000      0      0  30.0000       0
# 888         0       3  female  29.699118      1      2  23.4500       3
# 889         1       1    male  26.000000      0      0  30.0000       0
# 890         0       3    male  32.000000      0      0   7.7500       0
#
# [889 rows x 8 columns]

# %%
df.drop(['SibSp','Parch'],axis = 1, inplace = True)

# %%
df
# Out:
#      Survived  Pclass     Sex        Age     Fare  Family
# 0           0       3    male  22.000000   7.2500       1
# 1           1       1  female  38.000000  71.2833       1
# 2           1       3  female  26.000000   7.9250       0
# 3           1       1  female  35.000000  53.1000       1
# 4           0       3    male  35.000000   8.0500       0
# ..        ...     ...     ...        ...      ...     ...
# 886         0       2    male  27.000000  13.0000       0
# 887         1       1  female  19.000000  30.0000       0
# 888         0       3  female  29.699118  23.4500       3
# 889         1       1    male  26.000000  30.0000       0
# 890         0       3    male  32.000000   7.7500       0
#
# [889 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['sex'] = le.fit_transform(df['Sex'])

df
# Out:
#      Survived  Pclass     Sex        Age     Fare  Family  sex
# 0           0       3    male  22.000000   7.2500       1    1
# 1           1       1  female  38.000000  71.2833       1    0
# 2           1       3  female  26.000000   7.9250       0    0
# 3           1       1  female  35.000000  53.1000       1    0
# 4           0       3    male  35.000000   8.0500       0    1
# ..        ...     ...     ...        ...      ...     ...  ...
# 886         0       2    male  27.000000  13.0000       0    1
# 887         1       1  female  19.000000  30.0000       0    0
# 888         0       3  female  29.699118  23.4500       3    0
# 889         1       1    male  26.000000  30.0000       0    1
# 890         0       3    male  32.000000   7.7500       0    1
#
# [889 rows x 7 columns]

# %%
feature = df[['Pclass', 'Age', 'Fare', 'Family', 'sex']]
target = df.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split


X_train,X_test,y_train,y_test = train_test_split(feature,target,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
y_pred = logreg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

ac = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
cr = classification_report(y_test,y_pred)

print(f"Accuracy Score : {ac}\n{cm}\n\n{cr}")
# Out:
# Accuracy Score : 0.7921348314606742
# [[88 21]
#  [16 53]]
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       109
#            1       0.72      0.77      0.74        69
#
#     accuracy                           0.79       178
#    macro avg       0.78      0.79      0.78       178
# weighted avg       0.80      0.79      0.79       178

# %%
train = logreg.score(X_train,y_train)
test = logreg.score(X_test,y_test)

print(f"Training Score: {train}")
print(f"Testing Score: {test}")
# Out:
# Training Score: 0.7974683544303798
# Testing Score: 0.7921348314606742

# %% [markdown]
# **Forecast the new observation**

# %%
df
# Out:
#      Survived  Pclass     Sex        Age     Fare  Family  sex
# 0           0       3    male  22.000000   7.2500       1    1
# 1           1       1  female  38.000000  71.2833       1    0
# 2           1       3  female  26.000000   7.9250       0    0
# 3           1       1  female  35.000000  53.1000       1    0
# 4           0       3    male  35.000000   8.0500       0    1
# ..        ...     ...     ...        ...      ...     ...  ...
# 886         0       2    male  27.000000  13.0000       0    1
# 887         1       1  female  19.000000  30.0000       0    0
# 888         0       3  female  29.699118  23.4500       3    0
# 889         1       1    male  26.000000  30.0000       0    1
# 890         0       3    male  32.000000   7.7500       0    1
#
# [889 rows x 7 columns]

# %%
def survival_predictor():
  pclass = eval(input("Enter Passenger Class: "))
  gender = eval(input("For male Enter 1 and For female Enter 0: "))
  age = eval(input("Enter Age: "))
  fare = eval(input("Enter Fare: "))
  family = eval(input("Enter total number of member in a family: "))

  user_input = [pclass,gender,age,fare,family]
  v = logreg.predict([user_input])[0]

  if v == 1:
    print("Passenger will Survived")
  else:
    print("Passenger will Not Survived")

# %%
survival_predictor()
# Out:
# Enter Passenger Class: 2
# For male Enter 1 and For female Enter 0: 0
# Enter Age: 32
# Enter Fare: 100
# Enter total number of member in a family: 2
# Passenger will Not Survived
